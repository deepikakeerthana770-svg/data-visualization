# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40])

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={'maths':90,
      'physics':'85',
      'chemistry':'88'
     }
s=pd.Series(data)
print(s)
# Out:
# maths        90
# physics      85
# chemistry    88
# dtype: object

# %%
s=pd.Series([10,20,30,40])
print(s[0])
# Out:
# 10

# %%
s=pd.Series([100,200,300],
            index=['a','b','c'])
print(s['b'])
# Out:
# 200

# %%
print(s.shape)
# Out:
# (3,)

# %%
print(s.size)
# Out:
# 3

# %%
print(s.dtype)
# Out:
# int64

# %%
s=pd.Series([10,20,30,40])
print(s+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
print('sum=',s.sum())
print('mean=',s.mean())
print('maximum=',s.max())
print('minimum=',s.min())
# Out:
# sum= 100
# mean= 25.0
# maximum= 40
# minimum= 10

# %%
data={'RollNo':[101,102,103],
      'name':['Arun','Priya','Rahul'],
      'Marks':[85,90,78]
     }
df=pd.DataFrame(data)
print(df)
# Out:
#    RollNo   name  Marks
# 0     101   Arun     85
# 1     102  Priya     90
# 2     103  Rahul     78

# %%
df=pd.DataFrame(data, 
                index=['a','b','c'])         
print(df)
# Out:
#    RollNo   name  Marks
# a     101   Arun     85
# b     102  Priya     90
# c     103  Rahul     78

# %%
print(df.columns)
# Out:
# Index(['RollNo', 'name', 'Marks'], dtype='object')

# %%
print(df.index)
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
print(df.dtypes)
# Out:
# RollNo     int64
# name      object
# Marks      int64
# dtype: object

# %%
print(df['name'])
# Out:
# a     Arun
# b    Priya
# c    Rahul
# Name: name, dtype: object

# %%
print(df[['name','Marks']])
# Out:
#     name  Marks
# a   Arun     85
# b  Priya     90
# c  Rahul     78

# %%
print(df.loc['a'])
# Out:
# RollNo     101
# name      Arun
# Marks       85
# Name: a, dtype: object

# %%
print(df.loc['b'])
# Out:
# RollNo      102
# name      Priya
# Marks        90
# Name: b, dtype: object

# %%
print(df.loc[['a','c']])
# Out:
#    RollNo   name  Marks
# a     101   Arun     85
# c     103  Rahul     78

# %%
df['grade']=['A','A+','B']
print(df)
# Out:
#    RollNo   name  Marks grade
# a     101   Arun     85     A
# b     102  Priya     90    A+
# c     103  Rahul     78     B

# %%
df['Marks']=df['Marks']+5
print(df)
# Out:
#    RollNo   name  Marks grade
# a     101   Arun     90     A
# b     102  Priya     95    A+
# c     103  Rahul     83     B

# %%
df.drop('grade',
        axis=1,
        inplace=True)

# %%
print(df)
# Out:
#    RollNo   name  Marks
# a     101   Arun     90
# b     102  Priya     95
# c     103  Rahul     83

# %%
print(df['Marks'].sum())
# Out:
# 268

# %%
print(df['Marks'].mean())
# Out:
# 89.33333333333333

# %%
print(df['Marks'].max())
# Out:
# 95

# %%
df.sort_values("Marks")
# Out:
#    RollNo   name  Marks
# c     103  Rahul     83
# a     101   Arun     90
# b     102  Priya     95

# %%
print(df[df["Marks"]<90])
# Out:
#    RollNo   name  Marks
# c     103  Rahul     83

# %%
df.sort_values("Marks",ascending=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.sort_values("Marks",ascending=true)
#
# NameError: name 'true' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RollNo  3 non-null      int64
#  1   name    3 non-null      object
#  2   Marks   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.head()
# Out:
#    RollNo   name  Marks
# a     101   Arun     90
# b     102  Priya     95
# c     103  Rahul     83

# %%
df.tail()
# Out:
#    RollNo   name  Marks
# a     101   Arun     90
# b     102  Priya     95
# c     103  Rahul     83

# %%
df.describe()
# Out:
#        RollNo      Marks
# count     3.0   3.000000
# mean    102.0  89.333333
# std       1.0   6.027714
# min     101.0  83.000000
# 25%     101.5  86.500000
# 50%     102.0  90.000000
# 75%     102.5  92.500000
# max     103.0  95.000000

# %%
import pandas as pd
data={
    'roll no':[101,102,103,104,105,106,107],
    'name':['rishika','nethra','deepika','ajay','zion','vithya','ashvanth'],
    'department':['cs','ai','ds','dv','maths','physics','chem'],
    'marks':[96,88,90,83,77,99,98]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no      name department  marks
# 0      101   rishika         cs     96
# 1      102    nethra         ai     88
# 2      103   deepika         ds     90
# 3      104      ajay         dv     83
# 4      105      zion      maths     77
# 5      106    vithya    physics     99
# 6      107  ashvanth       chem     98

# %%
print(df['marks'].sum())
# Out:
# 631

# %%
print(df['marks'].mean())
# Out:
# 90.14285714285714

# %%
print(df['Marks'].sum())
